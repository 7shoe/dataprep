# %%
from pathlib import Path
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

from perf_vis_utils import load_cpu_frame, load_gpu_frame, plot_gpu_timeseries, plot_cpu_timeseries

# %%
parser = 'marker'

# Marker
f_gpu, f_perf = f'{parser}_gpu_logs.csv',  f'{parser}_perf_log.db'
p_root=Path('/eagle/projects/argonne_tpc/siebenschuh/aurora_gpt/performance_tracker/AdaParsePerformanceAnalysis')

# %%
parser = 'marker'

# CPU
df_cpu = load_cpu_frame(parser)
plot_cpu_timeseries(df_cpu, parser, 10)

# load
df_gpu = load_gpu_frame(parser)
plot_gpu_timeseries(df_gpu, parser, 10)
