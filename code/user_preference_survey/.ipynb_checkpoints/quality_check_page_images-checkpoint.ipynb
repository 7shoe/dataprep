# %%
import pandas as pd
from pathlib import Path
import yaml
import numpy as np

from table_utils import get_frames_of_choices_raw
from table_utils import get_sampled_choices

# %% [markdown]
# ## Quality check of page images AND text
# ~Before~ Only after sampling text, check if the page images **and the texts* are proper. Requires joint eye to see that the pages are not "off".

# %%
p_root=Path('/lus/eagle/projects/argonne_tpc/siebenschuh/aurora_gpt/joint')

# %%
df_train, df_test, df_val = get_frames_of_choices_raw()

unique_df = df_train[['path', 'page']].drop_duplicates()
sorted_df = unique_df.sort_values(by='page')
# Out:
# /home/siebenschuh/Projects/dataprep/code/user_preference_survey/table_utils.py:149: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(p_df, sep='|')

# %%
df_train[['path', 'page']]
# Out:
#         Unnamed: 0                                         path  page grobid  \
# 208004       12431  medrxiv/pdf/10.1101_2020.09.13.20193565.pdf     1      -
# 41486         7536                   arxiv/pdf/2408.00980v1.pdf     1      -
# 58668        11309                   arxiv/pdf/2408.02784v1.pdf     0      -
# 62754        47975                   arxiv/pdf/2408.03127v1.pdf     0      -
# 44433        33763                   arxiv/pdf/2408.01334v1.pdf     0      -
# ...            ...                                          ...   ...    ...
# 96283        15878    biorxiv/pdf/10.1101_2020.11.05.369918.pdf     0      -
# 54045        41358                   arxiv/pdf/2408.02344v1.pdf     0      -
# 15285         1322                   arxiv/pdf/2407.12440v1.pdf     1      -
# 74769        57344                   arxiv/pdf/2408.04560v1.pdf     1      -
# 215824       16324  medrxiv/pdf/10.1101_2020.12.15.20248173.pdf     1      -
#
#                                                      html  \
# 208004  draws radiographs from multiple hospital syste...
# 41486   fer clues about the distribution of accretion ...
# 58668   1 Introduction Behavioral biases have a profou...
# 62754   1 Introduction Large Language Models (LLMs) cu...
# 44433   I Introduction Understanding robot tasks encom...
# ...                                                   ...
# 96283   1. Introduction Autism spectrum disorders (ASD...
# 54045   Abstract Machine learning (ML) has revolutioni...
# 15285   of geometric principles vital for many machine...
# 74769    et al. (2022); Yang et al. (2023). Ye et al. ...
# 215824  can be expected to become effective. In order ...
#
#                                                    marker  \
# 208004  ed in these recent publications, but that also...
# 41486   . This system is composed of a black hole with...
# 58668   # Llm Economicus? Mapping The Behavioral Biase...
# 62754   # Lisbon Computational Linguists At Semeval-20...
# 44433   # A Backbone For Long-Horizon Robot Task Under...
# ...                                                   ...
# 96283   # Quantification Of Hypoperfusion In Autism As...
# 54045   # Title: Machine Learning Applications In Medi...
# 15285   et al. 2022b). During *Graph Construction*, ea...
# 74769   the outputs approved by the user serve as the ...
# 215824  e to understand how effective the various meas...
#
#                                                    nougat  \
# 208004  chitecture of deep convolutional neural networ...
# 41486   rolik, 2010). These polarized X-rays offer clu...
# 58668   # LLM economics? Mapping the Behavioral Biases...
# 62754   # Lisbon Computational Linguists at SemEval-20...
# 44433   A Backbone for Long-Horizon Robot Task Underst...
# ...                                                   ...
# 96283   bioRxiv preprint doi: [https://doi.org/10.1101...
# 54045   # Title: Machine Learning Applications in Medi...
# 15285   erations like convolution [1]. This has spurre...
# 74769   s.\n\nCPE is specifically designed for users w...
# 215824  to now - to the best of our knowledge - no oth...
#
#                                                   pymupdf  \
# 208004  2.1\nOverview of model and dataset constructio...
# 41486   2\nPublications of the Astronomical Society of...
# 58668   LLM economicus? Mapping the Behavioral Biases ...
# 62754   Lisbon Computational Linguists at SemEval-2024...
# 44433   A Backbone for Long-Horizon Robot Task Underst...
# ...                                                   ...
# 96283   Quantification of Hypoperfusion in Autism \nAs...
# 54045   arXiv:2408.02344v1  [cs.LG]  5 Aug 2024\n\nTit...
# 15285   Figure 1: Schematic of GraphGuard, inspired by...
# 74769   incorporated into the instruction, and the out...
# 215824  have taken drastic measures since early 2020 t...
#
#                                                     pypdf  \
# 208004  ttps://doi.org/10.1101/2020.09.13.20193565; th...
# 41486   ization —accretion, accretion disk — X–rays:bi...
# 58668   LLMeconomicus? MappingtheBehavioralBiasesofLLM...
# 62754         LisbonComputationalLinguistsatSemEval-20...
# 44433                                                   -
# ...                                                   ...
# 96283                                                   -
# 54045                                                   -
# 15285             interaction (Lebichot et al. 2017; D...
# 74769   ,andmore. Tomaximize thecapa-                 ...
# 215824  Gutenberg  School  of  Management  and  Econom...
#
#                                                 html_norm  ... bleu_marker  \
# 208004  draws radiographs from multiple hospital syste...  ...    0.693704
# 41486   fer clues about the distribution of accretion ...  ...    0.592781
# 58668   1 introduction behavioral biases have a profou...  ...    0.613404
# 62754   1 introduction large language models llms curr...  ...    0.577920
# 44433   i introduction understanding robot tasks encom...  ...    0.630884
# ...                                                   ...  ...         ...
# 96283   1 introduction autism spectrum disorders asd i...  ...    0.721570
# 54045   abstract machine learning ml has revolutionize...  ...    0.816797
# 15285   of geometric principles vital for many machine...  ...    0.683405
# 74769   et al 2022 yang et al 2023 ye et al 2023 propo...  ...    0.625094
# 215824  can be expected to become effective in order t...  ...    0.402758
#
#        rouge_marker  car_marker bleu_marker_norm rouge_marker_norm  \
# 208004     0.725780    0.790387         0.715603          0.721236
# 41486      0.661646    0.628287         0.610486          0.669978
# 58668      0.637427    0.556749         0.626985          0.638554
# 62754      0.648742    0.601053         0.630208          0.663543
# 44433      0.644340    0.583255         0.645005          0.657122
# ...             ...         ...              ...               ...
# 96283      0.727429    0.724577         0.727898          0.735346
# 54045      0.894845    0.893355         0.885729          0.902542
# 15285      0.706742    0.711525         0.718865          0.716318
# 74769      0.639437    0.630149         0.617932          0.631965
# 215824     0.398104    0.443671         0.401748          0.391586
#
#         car_marker_norm  subset  group  mean_bleu_score  pdf_id
# 208004         0.803807   train      B         0.698531  103624
# 41486          0.641254   train      B         0.673123  101115
# 58668          0.561472   train      B         0.606848  101509
# 62754          0.642531   train      B         0.606803  101597
# 44433          0.586976   train      B         0.644285  101183
# ...                 ...     ...    ...              ...     ...
# 96283          0.728345   train      B         0.792459  101978
# 54045          0.902513   train      A         0.846210  101416
# 15285          0.719298   train      B         0.697652  100428
# 74769          0.634040   train      B         0.610269  101880
# 215824         0.458153   train      B         0.638604  103655
#
# [1500 rows x 49 columns]
