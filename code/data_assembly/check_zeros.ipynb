# %%
import os
from pathlib import Path
import pandas as pd
import json
import numpy as np
import pymupdf

# %%
df_10240 = pd.read_csv('./testset_10240/df_10240.csv', sep='|')
# Out:
#                                                     path publisher  \
# 0                   nature/pdf/n_a_t_u_r_e_0_9_4_2_8.pdf    Nature
# 1      nature/pdf/s_4_1_5_8_6_-_0_2_2_-_0_5_3_1_3_-_9...    Nature
# 2      nature/pdf/s_4_1_5_8_6_-_0_2_2_-_0_5_3_9_1_-_9...    Nature
# 3      nature/pdf/s_4_1_5_8_6_-_0_2_2_-_0_5_4_8_2_-_7...    Nature
# 4                   nature/pdf/n_a_t_u_r_e_0_4_1_7_7.pdf    Nature
# ...                                                  ...       ...
# 10235        medrxiv/pdf/10.1101_2020.12.09.20246785.pdf   medrxiv
# 10236        medrxiv/pdf/10.1101_2023.08.30.23294810.pdf   medrxiv
# 10237        medrxiv/pdf/10.1101_2023.07.26.23293225.pdf   medrxiv
# 10238        medrxiv/pdf/10.1101_2021.10.08.21264745.pdf   medrxiv
# 10239        medrxiv/pdf/10.1101_2020.11.22.20236547.pdf   medrxiv
#
#                  class                                           subclass  \
# 0               Nature                                                  -
# ...

# %%
doc = pymupdf.open('./1536_modified/n_a_t_u_r_e_1_4_0_1_0.pdf')


doc[0].get_text('text')
# Out:
# 'Sample text content for the PDF. Sample text content for the PDF. Sample text content for the PDF. Sample text content for the PDF. Sample text content for the PD\n'
