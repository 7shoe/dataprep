# %%
import pandas as pd
import os
import torch
from pathlib import Path
from datasets import Dataset
from transformers import pipeline

# %% [markdown]
# ## Fill up Primary category `prim_cat`

# %%
# df
p = Path('/lus/eagle/projects/argonne_tpc/siebenschuh/aurora_gpt/database/meta_raw_table.csv')
df = pd.read_csv(p, sep='|')

# titles w/o primary category
title_list = list(df[(~df['title'].isna())]['title'])

# %%
len(title_list)
# Out:
# 16930

# %%
# Cahce DIR
os.environ['TRANSFORMERS_CACHE'] = '/eagle/projects/argonne_tpc/siebenschuh/HF_cache'

# Device
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# Initialize the zero-shot classification pipeline
classifier = pipeline('zero-shot-classification', model='facebook/bart-large-mnli', device=device)

# Scientific categories
labels = ["Biology", "Chemistry", "Physics", "Mathematics", "Computer Science", "Medicine", "Engineering", "Economics"]

# Scientific sub-categories
sub_labels = [
    "Astronomy",
    "Biotechnology",
    "Cancer Biology",
    "Cell Biology",
    "Climatology",
    "Evolutionary Biology",
    "Genetics",
    "Immunology",
    "Neuroscience",
    "Psychiatry",
    "Public Health",
    "Bioinformatics",
    "Biochemistry",
    "Bioengineering",
    "Biophysics",
    "Epidemiology",
    "Cardiovascular Medicine",
    "Oncology",
    "Neurology",
    "Mechanical Engineering",
    "Electrical Engineering",
    "Civil Engineering",
    "Chemical Engineering",
    "Environmental Engineering",
    "Industrial Engineering",
    "Aerospace Engineering",
    "Materials Science and Engineering",
    "Computer Engineering",
    "Architecture",
    "Analytical Chemistry",
    "Organic Chemistry",
    "Inorganic Chemistry",
    "Physical Chemistry",
    "Polymer Chemistry",
    "Microeconomics",
    "Macroeconomics",
    "Econometrics",
    "Development Economics",
    "Behavioral Economics",
    "Financial Economics",
    "Labor Economics",
    "Health Economics",
    "International Economics",
    "Environmental Economics",
    "Algebra",
    "Calculus",
    "Statistics",
    "Probability",
    "Geometry",
    "Topology",
    "Number Theory",
    "Mathematical Logic",
    "Discrete Mathematics",
    "Applied Mathematics",
    "Classical Mechanics",
    "Quantum Mechanics",
    "Thermodynamics",
    "Electromagnetism",
    "Optics",
    "Acoustics",
    "Nuclear Physics",
    "Condensed Matter Physics",
    "Particle Physics",
    "Astrophysics"
]

def classify_batch(batch):
    # Classify the titles into the main scientific category
    category_classifications = classifier(batch['title'], candidate_labels=labels, multi_label=False)
    top_categories = [classification['labels'][0] for classification in category_classifications]
    category_scores = [classification['scores'][0] for classification in category_classifications]
    
    # Classify the titles into the scientific sub-category
    subcategory_classifications = classifier(batch['title'], candidate_labels=sub_labels, multi_label=False)
    top_subcategories = [classification['labels'][0] for classification in subcategory_classifications]
    subcategory_scores = [classification['scores'][0] for classification in subcategory_classifications]
    
    return {
        'predicted_category': top_categories,
        'category_confidence': category_scores,
        'predicted_subcategory': top_subcategories,
        'subcategory_confidence': subcategory_scores
    }

# Actual Prediction
dataset = Dataset.from_dict({"title": title_list})

# Apply the classification function to the dataset in batches
classified_dataset = dataset.map(classify_batch, batched=True)

# Convert back to a list of dictionaries
classified_titles = classified_dataset.to_dict()

# Prediction table
df_pred = pd.DataFrame(classified_titles)

# store in `/lus/eagle/projects/argonne_tpc/siebenschuh/aurora_gpt/database/predicted_categories`

# %%
len(title_list)
# Out:
# 16930

# %%
df_pred
# Out:
#                                                 title predicted_category  \
# 0   Communities in C.elegans connectome through th...        Engineering
# 1   Self-organized vortex phases and hydrodynamic ...            Biology
# 2   Collective Arbitrage and the Value of Cooperation          Economics
# 3       Predicting Strategic Energy Storage Behaviors        Engineering
# 4   Optimally Coordinated Energy Management Framew...          Economics
# ..                                                ...                ...
# 95  Thought Graph: Generating Thought Process for ...            Biology
# 96  Discrete Laplacian thermostat for flocks and s...            Physics
# 97  Improved Dynamics for the Maximum Common Subgr...        Mathematics
# 98  Evolutionary Algorithms Simulating Molecular E...            Biology
# 99  Biophysics Informed Pathological Regularisatio...            Biology
#
#     category_confidence predicted_subcategory  subcategory_confidence
# 0              0.274968     Civil Engineering                0.102572
# 1              0.368099          Cell Biology                0.087583
# 2              0.472769        Macroeconomics                0.044785
# 3              0.253934           Probability                0.170267
# 4              0.356369           Probability                0.074423
# ..                  ...                   ...                     ...
# 95             0.782852        Bioinformatics                0.061667
# 96             0.254050   Applied Mathematics                0.083358
# 97             0.523249           Probability                0.055966
# 98             0.285143  Evolutionary Biology                0.057767
# 99             0.741642            Biophysics                0.822451
#
# [100 rows x 5 columns]

# %%
df.head()

# %%
classified_titles
# Out:
# {'title': ['Communities in C.elegans connectome through the prism of non-backtracking walks',
#   'Self-organized vortex phases and hydrodynamic interactions in Bos taurus sperm cells',
#   'Collective Arbitrage and the Value of Cooperation',
#   'Predicting Strategic Energy Storage Behaviors',
#   'Optimally Coordinated Energy Management Framework for Profit Maximization Considering Dispatchable and Non-Dispatchable Energy Resources',
#   'Decentralised Finance and Automated Market Making: Execution and Speculation',
#   'Information Arbitrage in Bipartite Heat Engines',
#   'Anisotropic body compliance facilitates robotic sidewinding in complex environments',
#   'Optimal Entry and Exit with Signature in Statistical Arbitrage',
#   'Shared Sequencing and Latency Competition as a Noisy Contest',
#   'Jaynes Machine: The universal microstructure of deep neural networks',
#   'Statistical arbitrage portfolio construction based on preference relations',
#   'ZeroSwap: Data-driven Optimal Market Making in DeFi',
#   'Perpetual Futures Pricing',
#   'Towards Understanding and Characterizing the Arbitrage Bot Scam In the Wild',
#   'High order universal portfolios',
#   'Discretization of continuous-time arbitrage strategies in financial markets with fractional Brownian motion',
#   'Pricing and hedging for a sticky diffusion',
#   'BioCLIP: A Vision Foundation Model for the Tree of Life',
#   'Deep Reinforcement Learning for Community Battery Scheduling under Uncertainties of Load, PV Generation, and Energy Prices',
#   'Invisible hand and arbitrage equilibrium in the self-organizing dynamics of pattern formation in ecological systems',
#   'Risk measures based on weak optimal transport',
#   'State-dependent complexity of the local field potential in the primary visual cortex',
#   'Exploring Key Aspects of Sea Level Rise and their Implications: An Overview',
#   'Physical models of bacterial chromosomes',
#   'Automated Market Maker on the XRP Ledger',
#   'PhysRFANet: Physics-Guided Neural Network for Real-Time Prediction of Thermal Effect During Radiofrequency Ablation Treatment',
#   'Superhedging Supermartingales',
#   'Dreaming of Electrical Waves: Generative Modeling of Cardiac Excitation Waves using Diffusion Models',
#   'Automated forest inventory: analysis of high-density airborne LiDAR point clouds with 3D deep learning',
#   'Single particle algorithms to reveal cellular nanodomain organization',
#   '$μ$GUIDE: a framework for quantitative imaging via generalized uncertainty-driven inference using deep learning',
#   'Distributional Reinforcement Learning-based Energy Arbitrage Strategies in Imbalance Settlement Mechanism',
#   'A framework for the valuation of insurance liabilities by production cost',
#   'An arbitrage driven price dynamics of Automated Market Makers in the presence of fees',
#   'Non-Atomic Arbitrage in Decentralized Finance',
#   'Short-time expansion of one-dimensional Fokker-Planck equations with heterogeneous diffusion',
#   'Levitated ferromagnetic magnetometer with energy resolution well below $\\hbar$',
#   'Expiring Assets in Automated Market Makers',
#   'Super-hedging-pricing formulas and Immediate-Profit arbitrage for market models under random horizon',
#   'Optimal control of ribosome population for gene expression under periodic nutrient intake',
#   'Impermanent Loss Conditions: An Analysis of Decentralized Exchange Platforms',
#   'Understanding Cellular Noise with Optical Perturbation and Deep Learning',
#   'Ambitions for theory in the physics of life',
#   'A Survey on Structure-Preserving Graph Transformers',
#   'Effective Bug Detection in Graph Database Engines: An LLM-based Approach',
#   'Linearly coupled quantum harmonic oscillators and their quantum entanglement',
#   'Neural Models and Algorithms for Sensorimotor Control of an Octopus Arm',
#   'A multiscale sensorimotor model of experience-dependent behavior in a minimal organism',
#   'Formalizing Automated Market Makers in the Lean 4 Theorem Prover',
#   'Closed-form solutions for generic N-token AMM arbitrage',
#   'A single-snapshot inverse solver for two-species graph model of tau pathology spreading in human Alzheimer disease',
#   'X-LoRA: Mixture of Low-Rank Adapter Experts, a Flexible Framework for Large Language Models with Applications in Protein Mechanics and Molecular Design',
#   'Message Detouring: A Simple Yet Effective Cycle Representation for Expressive Graph Learning',
#   'Finding Moving-Band Statistical Arbitrages via Convex-Concave Optimization',
#   'End-to-End Policy Learning of a Statistical Arbitrage Autoencoder Architecture',
#   'Tunable Shape Oscillations of Adaptive Droplets',
#   'Switchable optical trapping of Mie-resonant phase-change nanoparticles',
#   'Mechanism Design for Automated Market Makers',
#   'Transformer-based de novo peptide sequencing for data-independent acquisition mass spectrometry',
#   'An Evaluation of Large Language Models in Bioinformatics Research',
#   'Practical algorithms for Hierarchical overlap graphs',
#   'AI-powered simulation-based inference of a genuinely spatial-stochastic model of early mouse embryogenesis',
#   'Optimizing Neural Networks for Bermudan Option Pricing: Convergence Acceleration, Future Exposure Evaluation and Interpolation in Counterparty Credit Risk',
#   'FRAP analysis Measuring biophysical kinetic parameters using image analysis',
#   'Alternative models for FX: pricing double barrier options in regime-switching Lévy models with memory',
#   'A visualization tool to explore alphabet orderings for the Burrows-Wheeler Transform',
#   'Hyperdimensional computing: a fast, robust and interpretable paradigm for biological data',
#   'Exploring the Market Dynamics of Liquid Staking Derivatives (LSDs)',
#   'Exploring Gene Regulatory Interaction Networks and predicting therapeutic molecules for Hypopharyngeal Cancer and EGFR-mutated lung adenocarcinoma',
#   'BioT5+: Towards Generalized Biological Understanding with IUPAC Integration and Multi-task Tuning',
#   'Quanto Option Pricing on a Multivariate Levy Process Model with a Generative Artificial Intelligence',
#   'Direct measure of DNA bending by quantum magnetic imaging of a nano-mechanical torque-balance',
#   'OpenMEDLab: An Open-source Platform for Multi-modality Foundation Models in Medicine',
#   'Computing Minimal Absent Words and Extended Bispecial Factors with CDAWG Space',
#   'The Cost of Permissionless Liquidity Provision in Automated Market Makers',
#   'Radical Pair Mechanism and the Role of Chirality-Induced Spin Selectivity during Planaria Regeneration: Effect of Weak Magnetic Field on ROS levels',
#   'Analysis of Phylogeny Tracking Algorithms for Serial and Multiprocess Applications',
#   'Waves, patterns and bifurcations: a tutorial review on the vertebrate segmentation clock',
#   'Optimal Control of Underdamped Systems: An Analytic Approach',
#   'Chaining thoughts and LLMs to learn DNA structural biophysics',
#   'How to Find Long Maximal Exact Matches and Ignore Short Ones',
#   'Fluid ejections in nature',
#   'G4-Attention: Deep Learning Model with Attention for predicting DNA G-Quadruplexes',
#   'From Spectra to Biophysical Insights: End-to-End Learning with a Biased Radiative Transfer Model',
#   'am-AMM: An Auction-Managed Automated Market Maker',
#   'CIBRA identifies genomic alterations with a system-wide impact on tumor biology',
#   'Density and Affinity Dependent Social Segregation and Arbitrage Equilibrium in a Multi-class Schelling Game',
#   'A Learnable Prior Improves Inverse Tumor Growth Modeling',
#   'Correction and standardisation of lung oscillometry techniques using parameter inference: A study group report',
#   'Les Houches Lectures on Community Ecology: From Niche Theory to Statistical Mechanics',
#   'AGAThA: Fast and Efficient GPU Acceleration of Guided Sequence Alignment for Long Read Mapping',
#   'Modeling iPSC-derived Endothelial Cell Transition in Tumor Angiogenesis using Petri Nets',
#   'A perspective on active glassy dynamics in biological systems',
#   'Application of Quantum Tensor Networks for Protein Classification',
#   'Thought Graph: Generating Thought Process for Biological Reasoning',
#   'Discrete Laplacian thermostat for flocks and swarms: the fully conserved Inertial Spin Model',
#   'Improved Dynamics for the Maximum Common Subgraph Problem',
#   'Evolutionary Algorithms Simulating Molecular Evolution: A New Field Proposal',
#   'Biophysics Informed Pathological Regularisation for Brain Tumour Segmentation'],
#  'predicted_category': ['Engineering',
#   'Biology',
#   'Economics',
#   'Engineering',
#   'Economics',
#   'Economics',
#   'Engineering',
#   'Engineering',
#   'Mathematics',
#   'Computer Science',
#   'Computer Science',
#   'Economics',
#   'Economics',
#   'Economics',
#   'Computer Science',
#   'Engineering',
#   'Economics',
#   'Economics',
#   'Biology',
#   'Computer Science',
#   'Biology',
#   'Economics',
#   'Medicine',
#   'Economics',
#   'Biology',
#   'Economics',
#   'Physics',
#   'Engineering',
#   'Engineering',
#   'Computer Science',
#   'Physics',
#   'Computer Science',
#   'Economics',
#   'Economics',
#   'Economics',
#   'Economics',
#   'Mathematics',
#   'Physics',
#   'Economics',
#   'Economics',
#   'Biology',
#   'Computer Science',
#   'Computer Science',
#   'Physics',
#   'Engineering',
#   'Engineering',
#   'Physics',
#   'Engineering',
#   'Biology',
#   'Economics',
#   'Medicine',
#   'Biology',
#   'Physics',
#   'Computer Science',
#   'Mathematics',
#   'Computer Science',
#   'Physics',
#   'Physics',
#   'Engineering',
#   'Chemistry',
#   'Biology',
#   'Computer Science',
#   'Computer Science',
#   'Computer Science',
#   'Biology',
#   'Engineering',
#   'Computer Science',
#   'Biology',
#   'Economics',
#   'Medicine',
#   'Biology',
#   'Economics',
#   'Physics',
#   'Medicine',
#   'Computer Science',
#   'Economics',
#   'Physics',
#   'Computer Science',
#   'Biology',
#   'Engineering',
#   'Biology',
#   'Mathematics',
#   'Biology',
#   'Computer Science',
#   'Physics',
#   'Economics',
#   'Biology',
#   'Economics',
#   'Medicine',
#   'Medicine',
#   'Mathematics',
#   'Computer Science',
#   'Biology',
#   'Biology',
#   'Computer Science',
#   'Biology',
#   'Physics',
#   'Mathematics',
#   'Biology',
#   'Biology'],
#  'category_confidence': [0.2749681770801544,
#   0.3680991232395172,
#   0.4727689325809479,
#   0.25393372774124146,
#   0.3563692569732666,
#   0.3328096270561218,
#   0.5579672455787659,
#   0.3935657739639282,
#   0.3192598819732666,
#   0.31346431374549866,
#   0.5545811653137207,
#   0.24042735993862152,
#   0.4289201498031616,
#   0.5616311430931091,
#   0.245912566781044,
#   0.1369016170501709,
#   0.1947476714849472,
#   0.3454788327217102,
#   0.6925087571144104,
#   0.31902194023132324,
#   0.2247539758682251,
#   0.19980564713478088,
#   0.182906836271286,
#   0.16385671496391296,
#   0.47295331954956055,
#   0.21329647302627563,
#   0.9423555731773376,
#   0.19840236008167267,
#   0.26100459694862366,
#   0.4196484684944153,
#   0.20798452198505402,
#   0.5214512348175049,
#   0.2630847990512848,
#   0.44292309880256653,
#   0.3831190764904022,
#   0.22971439361572266,
#   0.6793038249015808,
#   0.6648252606391907,
#   0.3619411289691925,
#   0.2814153730869293,
#   0.3012833595275879,
#   0.26745328307151794,
#   0.2669267952442169,
#   0.9511239528656006,
#   0.2826635539531708,
#   0.42304936051368713,
#   0.7960020899772644,
#   0.3939100205898285,
#   0.40324240922927856,
#   0.43656817078590393,
#   0.19458089768886566,
#   0.30402860045433044,
#   0.2467069774866104,
#   0.5603509545326233,
#   0.535685122013092,
#   0.6567021608352661,
#   0.2573971450328827,
#   0.36790362000465393,
#   0.4821547567844391,
#   0.3066070079803467,
#   0.8674091696739197,
#   0.39456555247306824,
#   0.412190318107605,
#   0.34849873185157776,
#   0.2896600663661957,
#   0.2404807209968567,
#   0.23730649054050446,
#   0.704965353012085,
#   0.3091380298137665,
#   0.41750141978263855,
#   0.8458251953125,
#   0.3542482256889343,
#   0.5520488619804382,
#   0.8934045433998108,
#   0.44226041436195374,
#   0.6945834755897522,
#   0.32505232095718384,
#   0.6048263907432556,
#   0.412259578704834,
#   0.2626253664493561,
#   0.8664950132369995,
#   0.5704478025436401,
#   0.3487232029438019,
#   0.5031265020370483,
#   0.6837093830108643,
#   0.2675291895866394,
#   0.4842056334018707,
#   0.18551938235759735,
#   0.31485313177108765,
#   0.4094969928264618,
#   0.24852780997753143,
#   0.5002790689468384,
#   0.38028204441070557,
#   0.8644891977310181,
#   0.40250149369239807,
#   0.7828518748283386,
#   0.254050076007843,
#   0.523248553276062,
#   0.2851432263851166,
#   0.74164217710495],
#  'predicted_subcategory': ['Civil Engineering',
#   'Cell Biology',
#   'Macroeconomics',
#   'Probability',
#   'Probability',
#   'Topology',
#   'Probability',
#   'Probability',
#   'Statistics',
#   'Probability',
#   'Computer Engineering',
#   'Statistics',
#   'Development Economics',
#   'Probability',
#   'Probability',
#   'Probability',
#   'Probability',
#   'Probability',
#   'Evolutionary Biology',
#   'Probability',
#   'Applied Mathematics',
#   'Probability',
#   'Neuroscience',
#   'Probability',
#   'Cell Biology',
#   'Probability',
#   'Probability',
#   'Probability',
#   'Cardiovascular Medicine',
#   'Probability',
#   'Cell Biology',
#   'Probability',
#   'Probability',
#   'Probability',
#   'Probability',
#   'Probability',
#   'Applied Mathematics',
#   'Electromagnetism',
#   'Probability',
#   'Probability',
#   'Topology',
#   'Probability',
#   'Optics',
#   'Biophysics',
#   'Topology',
#   'Probability',
#   'Quantum Mechanics',
#   'Neuroscience',
#   'Biophysics',
#   'Probability',
#   'Applied Mathematics',
#   'Probability',
#   'Bioinformatics',
#   'Electromagnetism',
#   'Statistics',
#   'Architecture',
#   'Probability',
#   'Optics',
#   'Mechanical Engineering',
#   'Probability',
#   'Bioinformatics',
#   'Probability',
#   'Probability',
#   'Neuroscience',
#   'Biophysics',
#   'Probability',
#   'Topology',
#   'Bioinformatics',
#   'Financial Economics',
#   'Genetics',
#   'Bioengineering',
#   'Probability',
#   'Quantum Mechanics',
#   'Probability',
#   'Probability',
#   'Probability',
#   'Electromagnetism',
#   'Genetics',
#   'Topology',
#   'Econometrics',
#   'Biophysics',
#   'Probability',
#   'Probability',
#   'Genetics',
#   'Biophysics',
#   'Topology',
#   'Cancer Biology',
#   'Probability',
#   'Probability',
#   'Probability',
#   'Statistics',
#   'Computer Engineering',
#   'Cell Biology',
#   'Biophysics',
#   'Applied Mathematics',
#   'Bioinformatics',
#   'Applied Mathematics',
#   'Probability',
#   'Evolutionary Biology',
#   'Biophysics'],
#  'subcategory_confidence': [0.10257188975811005,
#   0.08758313208818436,
#   0.044785235077142715,
#   0.17026686668395996,
#   0.07442261278629303,
#   0.08548341691493988,
#   0.05154820531606674,
#   0.07104317843914032,
#   0.3570651710033417,
#   0.05106648802757263,
#   0.04768058657646179,
#   0.5483630299568176,
#   0.31725361943244934,
#   0.15859633684158325,
#   0.08152367174625397,
#   0.09270581603050232,
#   0.06180784851312637,
#   0.04924863204360008,
#   0.06473638117313385,
#   0.11492712795734406,
#   0.044035155326128006,
#   0.0524938628077507,
#   0.15380068123340607,
#   0.05668291449546814,
#   0.1219877079129219,
#   0.07704132795333862,
#   0.09457143396139145,
#   0.07453589141368866,
#   0.14690043032169342,
#   0.07231545448303223,
#   0.06051728129386902,
#   0.059994086623191833,
#   0.07165657728910446,
#   0.06073256954550743,
#   0.07500392198562622,
#   0.07008453458547592,
#   0.10944119840860367,
#   0.2632295787334442,
#   0.10039080679416656,
#   0.18915484845638275,
#   0.06419068574905396,
#   0.10870986431837082,
#   0.1283276379108429,
#   0.16669295728206635,
#   0.04988479241728783,
#   0.15989923477172852,
#   0.28040799498558044,
#   0.44745776057243347,
#   0.04499676451086998,
#   0.15332505106925964,
#   0.1495664417743683,
#   0.10968505591154099,
#   0.09584823250770569,
#   0.04713977128267288,
#   0.12547847628593445,
#   0.8273268342018127,
#   0.06763388216495514,
#   0.24863143265247345,
#   0.1152556985616684,
#   0.09942378103733063,
#   0.845044732093811,
#   0.07851849496364594,
#   0.09957900643348694,
#   0.3137332797050476,
#   0.13069111108779907,
#   0.07404882460832596,
#   0.060422632843256,
#   0.15935415029525757,
#   0.06464755535125732,
#   0.19553126394748688,
#   0.12450658529996872,
#   0.10007209330797195,
#   0.1259324699640274,
#   0.06467750668525696,
#   0.04743281379342079,
#   0.07465481758117676,
#   0.06735722720623016,
#   0.16414225101470947,
#   0.042452309280633926,
#   0.035327035933732986,
#   0.5721936225891113,
#   0.07189878076314926,
#   0.059553030878305435,
#   0.10685889422893524,
#   0.42639487981796265,
#   0.0540744848549366,
#   0.22517171502113342,
#   0.04016253724694252,
#   0.09196346253156662,
#   0.07537078857421875,
#   0.11687009036540985,
#   0.07039662450551987,
#   0.09320218861103058,
#   0.11662643402814865,
#   0.06684937328100204,
#   0.061667490750551224,
#   0.08335769921541214,
#   0.055965643376111984,
#   0.057767316699028015,
#   0.8224514126777649]}

# %%
# Out:
#                                                 title predicted_category  \
# 0   Communities in C.elegans connectome through th...        Engineering
# 1   Self-organized vortex phases and hydrodynamic ...            Biology
# 2   Collective Arbitrage and the Value of Cooperation          Economics
# 3       Predicting Strategic Energy Storage Behaviors        Engineering
# 4   Optimally Coordinated Energy Management Framew...          Economics
# ..                                                ...                ...
# 95  Thought Graph: Generating Thought Process for ...            Biology
# 96  Discrete Laplacian thermostat for flocks and s...            Physics
# 97  Improved Dynamics for the Maximum Common Subgr...        Mathematics
# 98  Evolutionary Algorithms Simulating Molecular E...            Biology
# 99  Biophysics Informed Pathological Regularisatio...            Biology
#
#     category_confidence predicted_subcategory  subcategory_confidence
# 0              0.274968     Civil Engineering                0.102572
# 1              0.368099          Cell Biology                0.087583
# 2              0.472769        Macroeconomics                0.044785
# 3              0.253934           Probability                0.170267
# 4              0.356369           Probability                0.074423
# ..                  ...                   ...                     ...
# 95             0.782852        Bioinformatics                0.061667
# 96             0.254050   Applied Mathematics                0.083358
# 97             0.523249           Probability                0.055966
# 98             0.285143  Evolutionary Biology                0.057767
# 99             0.741642            Biophysics                0.822451
#
# [100 rows x 5 columns]
