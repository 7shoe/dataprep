# %%
from matplotlib import pyplot as plt
from pathlib import Path
import pandas as pd 
import wandb

# %%
# WANDB API
api = wandb.Api()

# Project is specified by <entity/project-name>
runs = api.runs("7shoe/AdaParse-text-cls")

summary_list, config_list, name_list = [], [], []
for run in runs: 
    # .summary contains the output keys/values for metrics like accuracy.
    #  We call ._json_dict to omit large files 
    summary_list.append(run.summary._json_dict)

    # .config contains the hyperparameters.
    #  We remove special values that start with _.
    config_list.append(
        {k: v for k,v in run.config.items()
          if not k.startswith('_')})

    # .name is the human-readable name of the run.
    name_list.append(run.name)

# assemble initial DF
runs_df = pd.DataFrame({
    "summary": summary_list,
    "config": config_list,
    "name": name_list
    })

# merge
summary_df = pd.json_normalize(runs_df['summary'])
config_df = pd.json_normalize(runs_df['config'])
runs_df = runs_df.drop(columns=['summary', 'config'])
df = pd.concat([runs_df, summary_df, config_df], axis=1)

# 
#runs_df.to_csv("project.csv")

# %%
df
# Out:
#                      name     _runtime  _step    _timestamp  eval/accuracy  \
# 0          ruby-durian-31   320.137958   50.0  1.725841e+09       0.937618
# 1           eager-jazz-32   309.477750   50.0  1.725842e+09       0.948960
# 2           cosmic-sun-33   312.578679   50.0  1.725842e+09       0.960302
# 3       dandy-universe-34   309.226329   50.0  1.725842e+09       0.366730
# 4      frosty-snowball-35   309.578040   50.0  1.725843e+09       0.137996
# 5     stellar-aardvark-36   311.311980   50.0  1.725843e+09       0.291115
# 6      winter-snowball-37   309.367877   50.0  1.725843e+09       0.941399
# 7    flowing-waterfall-38   311.526562   50.0  1.725844e+09       0.947070
# 8        logical-music-39   312.462988   50.0  1.725844e+09       0.941399
# 9         lunar-plasma-40   309.458761   50.0  1.725844e+09       0.234405
# 10        solar-sponge-42   328.098767   50.0  1.725848e+09       0.948960
# 11     summer-darkness-43   313.895546   50.0  1.725848e+09       0.941399
# 12        solar-shadow-44   309.988911   50.0  1.725848e+09       0.960302
# 13        devoted-snow-45   311.763646   50.0  1.725849e+09       0.364839
# 14        lemon-planet-79   323.645963   50.0  1.725855e+09       0.546314
# 15  distinctive-durian-80   338.595221   50.0  1.725855e+09       0.525520
# 16       devoted-plant-81   337.190439   50.0  1.725855e+09       0.432892
# 17       playful-salad-82   338.185175   50.0  1.725856e+09       0.553875
# 18   vibrant-waterfall-83   343.704433   50.0  1.725856e+09       0.644612
# 19        apricot-pond-84   329.812994   50.0  1.725856e+09       0.255814
# 20          rose-grass-85   345.467150   50.0  1.725856e+09       0.534972
# 21         fancy-paper-86   323.562532   50.0  1.725857e+09       0.255814
# 22       logical-brook-87          NaN    NaN           NaN            NaN
# 23    dashing-darkness-88   322.662861   50.0  1.725857e+09       0.265262
# 24     vibrant-firefly-89   318.086265   50.0  1.725857e+09       0.546314
# 25          unique-sea-90   325.234532   50.0  1.725857e+09       0.255814
# 26   serene-wildflower-91   302.521409   50.0  1.725857e+09       0.567108
# 27   youthful-mountain-92  1039.501235  184.0  1.725858e+09       0.296512
# 28      revived-donkey-93   987.898034  184.0  1.725858e+09       0.308140
# 29        wobbly-smoke-94   319.716377   50.0  1.725858e+09       0.256541
# 30      hearty-terrain-95   305.785266   50.0  1.725858e+09       0.413989
# 31       lunar-firefly-96   324.998255   50.0  1.725858e+09       0.255814
# 32         lucky-paper-97   302.461871   50.0  1.725858e+09       0.529301
# 33        vivid-violet-98   306.227905   50.0  1.725858e+09       0.550095
# 34     clear-waterfall-99   325.435868   50.0  1.725858e+09       0.264535
# 35        fiery-field-100   827.844741  147.0  1.725859e+09       0.255814
# 36       avid-pyramid-101   827.566502  147.0  1.725859e+09       0.275436
# 37    gentle-darkness-102   303.271885   50.0  1.725859e+09       0.457467
# 38      rare-aardvark-103   317.464896   50.0  1.725859e+09       0.258721
# 39    spring-darkness-104   318.829595   50.0  1.725859e+09       0.255814
# 40   devout-resonance-105          NaN    NaN           NaN            NaN
#
#     eval/loss  eval/runtime  eval/samples_per_second  eval/steps_per_second  \
# 0    0.188318        1.5746                  335.953                 10.796
# 1    0.142073        1.5677                  337.438                 10.844
# 2    0.113811        1.5676                  337.461                 10.845
# 3    1.315822        1.5715                  336.624                 10.818
# 4    1.429405        1.5781                  335.223                 10.773
# 5    1.422359        1.5684                  337.295                 10.839
# 6    0.209608        1.5681                  337.354                 10.841
# 7    0.157897        1.5734                  336.217                 10.805
# 8    0.169597        1.5634                  338.355                 10.873
# 9    1.423826        1.5679                  337.402                 10.843
# 10   0.175417        1.5798                  334.850                 10.761
# 11   0.187472        1.5700                  336.933                 10.828
# 12   0.104149        1.5688                  337.205                 10.836
# 13   1.352241        1.5688                  337.211                 10.837
# 14   1.109173        1.5808                  334.641                 10.754
# 15   1.097618        1.5769                  335.474                 10.781
# 16   1.230654        1.5696                  337.021                 10.831
# 17   1.116578        1.5539                  340.442                 10.940
# 18   1.023721        1.5976                  331.113                 10.641
# 19   1.462749        3.9972                  344.243                 10.758
# 20   1.066632        1.5628                  338.503                 10.878
# 21   1.485806        4.0342                  341.085                 10.659
# 22        NaN           NaN                      NaN                    NaN
# 23   1.472068        4.0002                  343.981                 10.749
# 24   1.122755        1.5706                  336.822                 10.824
# 25   1.462835        3.9994                  344.048                 10.751
# 26   1.051654        1.5531                  340.611                 10.946
# 27   1.436874        9.5151                  144.612                 18.077
# 28   1.432771        9.3166                  147.693                 18.462
# 29   1.467464        4.0190                  342.372                 10.699
# 30   1.261898        1.5496                  341.371                 10.970
# 31   1.475479        3.9996                  344.038                 10.751
# 32   1.186340        1.5503                  341.222                 10.966
# 33   1.209041        1.5479                  341.764                 10.983
# 34   1.470707        4.0354                  340.985                 10.656
# 35   1.455290        8.3787                  164.226                  5.132
# 36   1.447350        8.3911                  163.983                  5.124
# 37   1.266391        1.5568                  339.797                 10.920
# 38   1.468739        3.9919                  344.697                 10.772
# 39   1.473899        4.0070                  343.402                 10.731
# 40        NaN           NaN                      NaN                    NaN
#
#     eval_accuracy  ...  peft_config.default.layers_to_transform  \
# 0        0.937618  ...                                      NaN
# 1        0.948960  ...                                      NaN
# 2        0.960302  ...                                      NaN
# 3        0.366730  ...                                      NaN
# 4        0.137996  ...                                      NaN
# 5        0.291115  ...                                      NaN
# 6        0.941399  ...                                      NaN
# 7        0.947070  ...                                      NaN
# 8        0.941399  ...                                      NaN
# 9        0.234405  ...                                      NaN
# 10       0.948960  ...                                      NaN
# 11       0.941399  ...                                      NaN
# 12       0.960302  ...                                      NaN
# 13       0.364839  ...                                      NaN
# 14       0.546314  ...                                      NaN
# 15       0.525520  ...                                      NaN
# 16       0.432892  ...                                      NaN
# 17       0.553875  ...                                      NaN
# 18       0.644612  ...                                      NaN
# 19       0.255814  ...                                      NaN
# 20       0.534972  ...                                      NaN
# 21       0.255814  ...                                      NaN
# 22            NaN  ...                                      NaN
# 23       0.265262  ...                                      NaN
# 24       0.546314  ...                                      NaN
# 25       0.255814  ...                                      NaN
# 26       0.567108  ...                                      NaN
# 27       0.296512  ...                                      NaN
# 28       0.308140  ...                                      NaN
# 29       0.256541  ...                                      NaN
# 30       0.413989  ...                                      NaN
# 31       0.255814  ...                                      NaN
# 32       0.529301  ...                                      NaN
# 33       0.550095  ...                                      NaN
# 34       0.264535  ...                                      NaN
# 35            NaN  ...                                      NaN
# 36            NaN  ...                                      NaN
# 37       0.457467  ...                                      NaN
# 38       0.258721  ...                                      NaN
# 39       0.255814  ...                                      NaN
# 40            NaN  ...                                      NaN
#
#     peft_config.default.base_model_name_or_path  \
# 0                             bert-base-uncased
# 1                             bert-base-uncased
# 2                             bert-base-uncased
# 3                             bert-base-uncased
# 4                             bert-base-uncased
# 5                             bert-base-uncased
# 6                             bert-base-uncased
# 7                             bert-base-uncased
# 8                             bert-base-uncased
# 9                             bert-base-uncased
# 10                            bert-base-uncased
# 11                            bert-base-uncased
# 12                            bert-base-uncased
# 13                            bert-base-uncased
# 14                            bert-base-uncased
# 15                            bert-base-uncased
# 16                            bert-base-uncased
# 17                            bert-base-uncased
# 18                            bert-base-uncased
# 19                            bert-base-uncased
# 20                            bert-base-uncased
# 21                            bert-base-uncased
# 22                                          NaN
# 23                            bert-base-uncased
# 24                            bert-base-uncased
# 25                            bert-base-uncased
# 26                            bert-base-uncased
# 27                            bert-base-uncased
# 28                            bert-base-uncased
# 29                            bert-base-uncased
# 30                            bert-base-uncased
# 31                            bert-base-uncased
# 32                            bert-base-uncased
# 33                            bert-base-uncased
# 34                            bert-base-uncased
# 35                            bert-base-uncased
# 36                            bert-base-uncased
# 37                            bert-base-uncased
# 38                            bert-base-uncased
# 39                            bert-base-uncased
# 40                                          NaN
#
#     accelerator_config.even_batches  accelerator_config.non_blocking  \
# 0                              True                            False
# 1                              True                            False
# 2                              True                            False
# 3                              True                            False
# 4                              True                            False
# 5                              True                            False
# 6                              True                            False
# 7                              True                            False
# 8                              True                            False
# 9                              True                            False
# 10                             True                            False
# 11                             True                            False
# 12                             True                            False
# 13                             True                            False
# 14                             True                            False
# 15                             True                            False
# 16                             True                            False
# 17                             True                            False
# 18                             True                            False
# 19                             True                            False
# 20                             True                            False
# 21                             True                            False
# 22                              NaN                              NaN
# 23                             True                            False
# 24                             True                            False
# 25                             True                            False
# 26                             True                            False
# 27                             True                            False
# 28                             True                            False
# 29                             True                            False
# 30                             True                            False
# 31                             True                            False
# 32                             True                            False
# 33                             True                            False
# 34                             True                            False
# 35                             True                            False
# 36                             True                            False
# 37                             True                            False
# 38                             True                            False
# 39                             True                            False
# 40                              NaN                              NaN
#
#     accelerator_config.split_batches  accelerator_config.dispatch_batches  \
# 0                              False                                  NaN
# 1                              False                                  NaN
# 2                              False                                  NaN
# 3                              False                                  NaN
# 4                              False                                  NaN
# 5                              False                                  NaN
# 6                              False                                  NaN
# 7                              False                                  NaN
# 8                              False                                  NaN
# 9                              False                                  NaN
# 10                             False                                  NaN
# 11                             False                                  NaN
# 12                             False                                  NaN
# 13                             False                                  NaN
# 14                             False                                  NaN
# 15                             False                                  NaN
# 16                             False                                  NaN
# 17                             False                                  NaN
# 18                             False                                  NaN
# 19                             False                                  NaN
# 20                             False                                  NaN
# 21                             False                                  NaN
# 22                               NaN                                  NaN
# 23                             False                                  NaN
# 24                             False                                  NaN
# 25                             False                                  NaN
# 26                             False                                  NaN
# 27                             False                                  NaN
# 28                             False                                  NaN
# 29                             False                                  NaN
# 30                             False                                  NaN
# 31                             False                                  NaN
# 32                             False                                  NaN
# 33                             False                                  NaN
# 34                             False                                  NaN
# 35                             False                                  NaN
# 36                             False                                  NaN
# 37                             False                                  NaN
# 38                             False                                  NaN
# 39                             False                                  NaN
# 40                               NaN                                  NaN
#
#     accelerator_config.use_seedable_sampler  \
# 0                                      True
# 1                                      True
# 2                                      True
# 3                                      True
# 4                                      True
# 5                                      True
# 6                                      True
# 7                                      True
# 8                                      True
# 9                                      True
# 10                                     True
# 11                                     True
# 12                                     True
# 13                                     True
# 14                                     True
# 15                                     True
# 16                                     True
# 17                                     True
# 18                                     True
# 19                                     True
# 20                                     True
# 21                                     True
# 22                                      NaN
# 23                                     True
# 24                                     True
# 25                                     True
# 26                                     True
# 27                                     True
# 28                                     True
# 29                                     True
# 30                                     True
# 31                                     True
# 32                                     True
# 33                                     True
# 34                                     True
# 35                                     True
# 36                                     True
# 37                                     True
# 38                                     True
# 39                                     True
# 40                                      NaN
#
#     accelerator_config.gradient_accumulation_kwargs  id2label.4  \
# 0                                               NaN         NaN
# 1                                               NaN         NaN
# 2                                               NaN         NaN
# 3                                               NaN         NaN
# 4                                               NaN         NaN
# 5                                               NaN         NaN
# 6                                               NaN         NaN
# 7                                               NaN         NaN
# 8                                               NaN         NaN
# 9                                               NaN         NaN
# 10                                              NaN         NaN
# 11                                              NaN         NaN
# 12                                              NaN         NaN
# 13                                              NaN         NaN
# 14                                              NaN         NaN
# 15                                              NaN         NaN
# 16                                              NaN         NaN
# 17                                              NaN         NaN
# 18                                              NaN         NaN
# 19                                              NaN     LABEL_4
# 20                                              NaN         NaN
# 21                                              NaN     LABEL_4
# 22                                              NaN         NaN
# 23                                              NaN     LABEL_4
# 24                                              NaN         NaN
# 25                                              NaN     LABEL_4
# 26                                              NaN         NaN
# 27                                              NaN     LABEL_4
# 28                                              NaN     LABEL_4
# 29                                              NaN     LABEL_4
# 30                                              NaN         NaN
# 31                                              NaN     LABEL_4
# 32                                              NaN         NaN
# 33                                              NaN         NaN
# 34                                              NaN     LABEL_4
# 35                                              NaN     LABEL_4
# 36                                              NaN     LABEL_4
# 37                                              NaN         NaN
# 38                                              NaN     LABEL_4
# 39                                              NaN     LABEL_4
# 40                                              NaN         NaN
#
#     label2id.LABEL_4
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# 5                NaN
# 6                NaN
# 7                NaN
# 8                NaN
# 9                NaN
# 10               NaN
# 11               NaN
# 12               NaN
# 13               NaN
# 14               NaN
# 15               NaN
# 16               NaN
# 17               NaN
# 18               NaN
# 19               4.0
# 20               NaN
# 21               4.0
# 22               NaN
# 23               4.0
# 24               NaN
# 25               4.0
# 26               NaN
# 27               4.0
# 28               4.0
# 29               4.0
# 30               NaN
# 31               4.0
# 32               NaN
# 33               NaN
# 34               4.0
# 35               4.0
# 36               4.0
# 37               NaN
# 38               4.0
# 39               4.0
# 40               NaN
#
# [41 rows x 284 columns]
